# %% [markdown]
# <a href="https://colab.research.google.com/github/amgabatbayar/Uczenie-Maszynowe-w-Finansach---Marcin-Batbayar/blob/UseCase2/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# !pip install surprise
from surprise import SVD, KNNWithMeans
from surprise.model_selection import GridSearchCV
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate
# Out:
# Requirement already satisfied: surprise in /usr/local/lib/python3.10/dist-packages (0.1)
# Requirement already satisfied: scikit-surprise in /usr/local/lib/python3.10/dist-packages (from surprise) (1.1.3)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.4.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.25.2)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-surprise->surprise) (1.11.4)

# %% [markdown]
# ## Przygotowanie danych

# %%
ratings = pd.read_csv('https://s3-us-west-2.amazonaws.com/recommender-tutorial/ratings.csv')
movies = pd.read_csv('https://s3-us-west-2.amazonaws.com/recommender-tutorial/movies.csv')
movies[8210:8300]
# Out:
#       movieId                                        title  \
# 8210   103543                        Lifeguard, The (2013)
# 8211   103596                             Sharknado (2013)
# 8212   103602      Craig Ferguson: I'm Here To Help (2013)
# 8213   103606                         Stuck in Love (2012)
# 8214   103609                             Class Act (1992)
# ...       ...                                          ...
# 8295   106487       The Hunger Games: Catching Fire (2013)
# 8296   106489  Hobbit: The Desolation of Smaug, The (2013)
# 8297   106491                              47 Ronin (2013)
# 8298   106540                          Delivery Man (2013)
# 8299   106542                    Charlie Countryman (2013)
#
#                             genres
# 8210                  Comedy|Drama
# 8211                        Sci-Fi
# 8212            Comedy|Documentary
# 8213          Comedy|Drama|Romance
# 8214                        Comedy
# ...                            ...
# 8295  Action|Adventure|Sci-Fi|IMAX
# 8296        Adventure|Fantasy|IMAX
# 8297      Action|Adventure|Fantasy
# 8298                        Comedy
# 8299         Action|Comedy|Romance
#
# [90 rows x 3 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %%
ratings
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# ...        ...      ...     ...         ...
# 100831     610   166534     4.0  1493848402
# 100832     610   168248     5.0  1493850091
# 100833     610   168250     5.0  1494273047
# 100834     610   168252     5.0  1493846352
# 100835     610   170875     3.0  1493846415
#
# [100836 rows x 4 columns]

# %%
movies
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# ## 1.1 Podaj liczbę filmów Sci-Fi

# %%
sci_fi = movies[movies['genres'].str.contains('Sci-Fi')]
sci_fi_count = sci_fi.shape[0]
sci_fi_count
print(f"Ilość filmów Sci-Fi: {sci_fi_count}")
# Out:
# Ilość filmów Sci-Fi: 980

# %% [markdown]
# ## 1.2 Pokaż rozkład ocen komedii

# %%
sns.countplot(data=ratings, x='rating', palette="viridis")
plt.title("Distribution of movie ratings", fontsize=14)
plt.show()
# Out:
# <ipython-input-70-a936a50247a6>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=ratings, x='rating', palette="viridis")

# %% [markdown]
# ## 1.3 Podaj średnią ocen wszystkich filmów akcji oraz 3 filmy najwyżej ocenianych

# %%
# Filtuje filmy akcji
action_movies = movies[movies['genres'].str.contains('Action')]

# Łącze df z ocenami
action_movies = pd.merge(action_movies, ratings, on='movieId')

# Średnia dla każdego filmu
srednia_akcji = action_movies['rating'].mean()

# Średnia globalna
avg_ratings = action_movies.groupby('title')['rating'].mean()
# top3
top3 = avg_ratings.nlargest(3)

print(f"Średnia dla filmów akcji wynosi: {srednia_akcji}")
print(f"To są 3 najwyżej oceniane filmy: {top3}")
# Out:
# Średnia dla filmów akcji wynosi: 3.447984331646809
# To są 3 najwyżej oceniane filmy: title
# Alien Contamination (1980)                                         5.0
# Assignment, The (1997)                                             5.0
# Battle Royale 2: Requiem (Batoru rowaiaru II: Chinkonka) (2003)    5.0
# Name: rating, dtype: float64

# %%
# 2 metoda
movie_ratings = ratings.merge(movies[movies['genres'].str.contains('Action')], on='movieId')
rating_akcji = movie_ratings['rating'].mean()

# Teraz obliczamy średnią ocen dla każdego filmu akcji oraz liczbę głosów
srednia = movie_ratings.groupby('title').agg({'rating': ['mean', 'count']}).reset_index()

# df
srednia.columns = ['title', 'mean_rating', 'count_rating']

# Sortujemy filmy akcji według średniej oceny, ale tylko te z liczbą głosów wyższą od ustalonego progu

sortowanie1 = srednia[srednia['count_rating'] >= 17]
sortowanie2 = srednia[srednia['count_rating'] >= 50]

# Wybieramy trzy filmy akcji z najwyższą średnią oceną
top3_sort1 = sortowanie1.sort_values(by='mean_rating', ascending=False).head(3)
top3_sort2 = sortowanie2.sort_values(by='mean_rating', ascending=False).head(3)

print(f"Według tej metody to są 3 najwyżej oceniane filmy:\n{top3_sort1}")
print(f"Według tej metody to są 3 najwyżej oceniane filmy:\n{top3_sort2}")
print(f"Średnia ilość głosów na film akcji to: 17, dlatego tutaj przyjąłem próg 17 oraz 50 - ale to już mój pomysł")
# Out:
# Według tej metody to są 3 najwyżej oceniane filmy:
#                                                   title  mean_rating  \
# 1173  Once Upon a Time in the West (C'era una volta ...     4.305556
# 972                                        Logan (2017)     4.280000
# 551                                   Fight Club (1999)     4.272936
#
#       count_rating
# 1173            18
# 972             25
# 551            218
# Według tej metody to są 3 najwyżej oceniane filmy:
#                            title  mean_rating  count_rating
# 551            Fight Club (1999)     4.272936           218
# 374      Dark Knight, The (2008)     4.238255           149
# 1255  Princess Bride, The (1987)     4.232394           142
# Średnia ilość głosów na film akcji to: 17, dlatego tutaj przyjąłem próg 17 oraz 50 - ale to już mój pomysł

# %% [markdown]
# ## 2.1 Zbuduj system na podstawie algorytmu SVD oraz kNNwithMeans

# %%
reader = Reader(rating_scale=(ratings['rating'].min(), ratings['rating'].max()))
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)
svd = SVD()
cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8755  0.8730  0.8776  0.8687  0.8757  0.8741  0.0031
# MAE (testset)     0.6730  0.6707  0.6732  0.6670  0.6741  0.6716  0.0025
# Fit time          1.60    2.76    3.81    3.45    2.88    2.90    0.75
# Test time         0.14    0.31    0.52    0.27    0.28    0.30    0.12
# {'test_rmse': array([0.87548119, 0.87295569, 0.87757657, 0.8687279 , 0.87571647]),
#  'test_mae': array([0.67297195, 0.670747  , 0.67318701, 0.6670295 , 0.67412118]),
#  'fit_time': (1.6044189929962158,
#   2.759260416030884,
#   3.8051936626434326,
#   3.450242519378662,
#   2.875559091567993),
#  'test_time': (0.1389484405517578,
#   0.30632615089416504,
#   0.5242612361907959,
#   0.272066593170166,
#   0.2759366035461426)}

# %%
knn = KNNWithMeans()
cross_validate(knn, data, measures=['RMSE', 'MAE'], cv=5, verbose=True)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Computing the msd similarity matrix...
# Done computing similarity matrix.
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8919  0.9019  0.8969  0.8946  0.9001  0.8971  0.0036
# MAE (testset)     0.6835  0.6901  0.6858  0.6822  0.6867  0.6857  0.0027
# Fit time          0.15    0.17    0.23    0.17    0.17    0.18    0.03
# Test time         1.47    2.16    1.67    1.47    1.48    1.65    0.27
# {'test_rmse': array([0.8919131 , 0.90192426, 0.89690423, 0.89462656, 0.90008884]),
#  'test_mae': array([0.6835003 , 0.69012164, 0.68578882, 0.68218785, 0.68669912]),
#  'fit_time': (0.1495811939239502,
#   0.16752934455871582,
#   0.23136043548583984,
#   0.16976475715637207,
#   0.1708543300628662),
#  'test_time': (1.4672667980194092,
#   2.1634650230407715,
#   1.6728808879852295,
#   1.4692561626434326,
#   1.4759125709533691)}

# %% [markdown]
# ## 2.2 Czym różni się algorytm kNN with means od standardowego kNN?
# kNN: Przypisuje nowy punkt do klasy na podstawie etykiet najbliższych sąsiadów.
#
# kNN with means: Oprócz etykiet, uwzględnia również średnią wartość cech sąsiadów, w tym przypadku uwzględnia średnią ocenę.
#
# W standardowym algorytmie kNN, przypisujemy nowy punkt do klasy na podstawie etykiet jego najbliższych sąsiadów. Jednak w przypadku kNN with means, obliczamy również średnią wartość cech dla tych sąsiadów i używamy jej do przewidywania klasy

# %% [markdown]
# ## 2.3 Wykorzystaj metodę hiperparametryzacji GridSearch do wyboru liczby sąsiadów od 2-6

# %% [markdown]
# ## dla kNNwithMeans

# %%
#KNN
reader = Reader(rating_scale=(ratings['rating'].min(), ratings['rating'].max()))
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# Define a parameter grid
param_grid = {'k': [2, 3, 4, 5, 6]}

# Initialize GridSearchCV
gs = GridSearchCV(KNNWithMeans, param_grid, measures=['rmse', 'mae'], cv=3, n_jobs=-1)

# Fit GridSearchCV
gs.fit(data)

# Best score and best parameters
best_rmse = gs.best_score['rmse']
best_params = gs.best_params['rmse']

print("Best RMSE: ", best_rmse)
print("Best parameters: ", best_params)
# Out:
# Best RMSE:  0.9292948791810014
# Best parameters:  {'k': 6}

# %% [markdown]
# ## 3. Rekomendacje

# %%
sim_options = {
    'name': 'cosine',
    'user_based': False  # obliczenia na podstawie podobieństwa między przedmiotami
}

algo = KNNWithMeans(sim_options=sim_options)
algo.fit(trainset)

# Wyszukiwanie sąsiadów dla filmów
jumanji_neighbors = algo.get_neighbors(jumanji_id, k=6)
flint_neighbors = algo.get_neighbors(flint_id, k=6)

# Konwersja movieId na tytuły filmów
jumanji_recommendations = movies[movies['movieId'].isin(jumanji_neighbors)]['title'].tolist()
flint_recommendations = movies[movies['movieId'].isin(flint_neighbors)]['title'].tolist()

print("Nowe rekomendacje po obejrzeniu 'Jumanji':", jumanji_recommendations)
print("Nowe rekomendacje po obejrzeniu 'Flint':", flint_recommendations)
# Out:
# Computing the cosine similarity matrix...
# Done computing similarity matrix.
# Nowe rekomendacje po obejrzeniu 'Jumanji': ['In the Bleak Midwinter (1995)', 'Braveheart (1995)', 'Crimson Tide (1995)', 'Jerky Boys, The (1995)', 'Mixed Nuts (1994)', 'Miami Rhapsody (1995)']
# Nowe rekomendacje po obejrzeniu 'Flint': ['Jury Duty (1995)', 'Disclosure (1994)', 'My Family (1995)', 'Murder in the First (1995)', 'Pulp Fiction (1994)', 'Quiz Show (1994)']

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings[['userId', 'movieId', 'rating']], reader)

# Budowanie pełnego zestawu danych treningowych
trainset = data.build_full_trainset()

# Trenowanie algorytmu SVD
svd = SVD()
svd.fit(trainset)

# Znajdź movieId dla "Jumanji" i "Flint"
jumanji_id = movies[movies['title'].str.contains('Jumanji', na=False)]['movieId'].values[0]
flint_id = movies[movies['title'].str.contains('Flint', na=False)]['movieId'].values[0]

# Znajdź użytkowników, którzy ocenili te filmy
jumanji_users = ratings[ratings['movieId'] == jumanji_id]['userId'].unique()
flint_users = ratings[ratings['movieId'] == flint_id]['userId'].unique()

# Zbierz rekomendacje
def get_recommendations(movie_id, user_ids):
    recommendations = {}
    for user_id in user_ids:
        user_ratings = ratings[ratings['userId'] == user_id]
        user_unrated_movies = movies[~movies['movieId'].isin(user_ratings['movieId'])]
        predicted_scores = [svd.predict(user_id, movie_id).est for movie_id in user_unrated_movies['movieId']]
        top_scores_indices = sorted(range(len(predicted_scores)), key=lambda i: predicted_scores[i], reverse=True)[:5]
        top_movie_ids = user_unrated_movies.iloc[top_scores_indices]['movieId']
        top_movie_titles = movies[movies['movieId'].isin(top_movie_ids)]['title'].tolist()
        recommendations[user_id] = top_movie_titles
    return recommendations

# Wyznacz rekomendacje dla użytkowników, którzy oglądali Jumanji i Flint
jumanji_recommendations = get_recommendations(jumanji_id, jumanji_users)
flint_recommendations = get_recommendations(flint_id, flint_users)
lol222 = get_recommendations(jumanji_recommendations, flint_recommendations)
print("Rekomendacje po obejrzeniu 'Jumanji':", jumanji_recommendations)
print("Rekomendacje po obejrzeniu 'Flint':", flint_recommendations)
print("Rekomendacje po obejrzeniu 'Flint':", lol222)
# Out:
# Rekomendacje po obejrzeniu 'Jumanji': {6: ['Star Wars: Episode IV - A New Hope (1977)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Wallace & Gromit: A Close Shave (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode VI - Return of the Jedi (1983)'], 8: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Rear Window (1954)', 'Boot, Das (Boat, The) (1981)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Fight Club (1999)'], 18: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Casablanca (1942)', 'Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Boot, Das (Boat, The) (1981)'], 19: ['Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Seven Samurai (Shichinin no samurai) (1954)', 'Life Is Beautiful (La Vita è bella) (1997)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)'], 20: ['Pulp Fiction (1994)', 'Sting, The (1973)', 'American Beauty (1999)', 'Old Boy (2003)', 'Inception (2010)'], 21: ['Secrets & Lies (1996)', 'Streetcar Named Desire, A (1951)', 'Paths of Glory (1957)', 'Lawrence of Arabia (1962)', 'In Bruges (2008)'], 27: ['Casablanca (1942)', 'Streetcar Named Desire, A (1951)', 'Femme Nikita, La (Nikita) (1990)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Three Billboards Outside Ebbing, Missouri (2017)'], 51: ['Philadelphia Story, The (1940)', 'American Beauty (1999)', 'Boondock Saints, The (2000)', 'Kill Bill: Vol. 1 (2003)', 'Grand Budapest Hotel, The (2014)'], 62: ['Lawrence of Arabia (1962)', 'Apocalypse Now (1979)', 'Goodfellas (1990)', 'Cool Hand Luke (1967)', 'There Will Be Blood (2007)'], 68: ['Lawrence of Arabia (1962)', 'Patton (1970)', 'Miracle on 34th Street (1947)', 'Badlands (1973)', 'Dogville (2003)'], 82: ['Shawshank Redemption, The (1994)', "Monty Python's Life of Brian (1979)", 'Lawrence of Arabia (1962)', 'Great Escape, The (1963)', "Monty Python's And Now for Something Completely Different (1971)"], 91: ['Chinatown (1974)', 'General, The (1926)', 'Gallipoli (1981)', 'District 9 (2009)', 'Inception (2010)'], 93: ['Hoop Dreams (1994)', 'Wallace & Gromit: The Best of Aardman Animation (1996)', 'Godfather, The (1972)', 'It Happened One Night (1934)', 'Notorious (1946)'], 94: ['Star Wars: Episode IV - A New Hope (1977)', 'Godfather, The (1972)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Star Wars: Episode VI - Return of the Jedi (1983)', 'Snatch (2000)'], 103: ['Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Dial M for Murder (1954)', 'Monty Python and the Holy Grail (1975)', 'Great Escape, The (1963)', 'Cool Hand Luke (1967)'], 104: ['Philadelphia Story, The (1940)', 'Double Indemnity (1944)', 'Snatch (2000)', 'There Will Be Blood (2007)', 'Three Billboards Outside Ebbing, Missouri (2017)'], 107: ['Forrest Gump (1994)', 'Lawrence of Arabia (1962)', 'Raging Bull (1980)', 'Cool Hand Luke (1967)', 'Celebration, The (Festen) (1998)'], 112: ['Pulp Fiction (1994)', 'Shawshank Redemption, The (1994)', 'Godfather, The (1972)', 'Bridge on the River Kwai, The (1957)', 'Fight Club (1999)'], 117: ['Star Wars: Episode IV - A New Hope (1977)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Raging Bull (1980)', 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Lord of the Rings: The Return of the King, The (2003)'], 122: ['Blade Runner (1982)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Rear Window (1954)', 'Wallace & Gromit: The Wrong Trousers (1993)'], 125: ['Streetcar Named Desire, A (1951)', 'Lawrence of Arabia (1962)', 'Apocalypse Now (1979)', 'Touch of Evil (1958)', 'Boondock Saints, The (2000)'], 135: ['Reservoir Dogs (1992)', 'Lawrence of Arabia (1962)', 'Apocalypse Now (1979)', 'For a Few Dollars More (Per qualche dollaro in più) (1965)', 'Fog of War: Eleven Lessons from the Life of Robert S. McNamara, The (2003)'], 140: ['Amade ...
# Rekomendacje po obejrzeniu 'Flint': {6: ['Star Wars: Episode IV - A New Hope (1977)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Wallace & Gromit: A Close Shave (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode VI - Return of the Jedi (1983)'], 15: ['Hoop Dreams (1994)', 'Goodfellas (1990)', 'Indiana Jones and the Last Crusade (1989)', 'Good Will Hunting (1997)', 'Run Lola Run (Lola rennt) (1998)'], 21: ['Secrets & Lies (1996)', 'Streetcar Named Desire, A (1951)', 'Paths of Glory (1957)', 'Lawrence of Arabia (1962)', 'In Bruges (2008)'], 38: ['Godfather, The (1972)', 'Casablanca (1942)', 'Godfather: Part II, The (1974)', 'Fight Club (1999)', 'Hustler, The (1961)'], 43: ['Sense and Sensibility (1995)', 'Persuasion (1995)', 'Dead Man Walking (1995)', 'Usual Suspects, The (1995)', 'Lamerica (1994)'], 57: ['Shawshank Redemption, The (1994)', 'Brazil (1985)', 'Army of Darkness (1993)', 'Fight Club (1999)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"], 64: ["Monty Python's Life of Brian (1979)", 'Brazil (1985)', 'Boot, Das (Boat, The) (1981)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'There Will Be Blood (2007)'], 68: ['Lawrence of Arabia (1962)', 'Patton (1970)', 'Miracle on 34th Street (1947)', 'Badlands (1973)', 'Dogville (2003)'], 109: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Casablanca (1942)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Departed, The (2006)', 'There Will Be Blood (2007)'], 132: ['Lawrence of Arabia (1962)', 'Goodfellas (1990)', 'Amadeus (1984)', 'Sting, The (1973)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)'], 136: ['Shawshank Redemption, The (1994)', 'Great Escape, The (1963)', 'Fight Club (1999)', 'For a Few Dollars More (Per qualche dollaro in più) (1965)', 'Lord of the Rings: The Return of the King, The (2003)'], 170: ['North by Northwest (1959)', "One Flew Over the Cuckoo's Nest (1975)", 'Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)'], 177: ['Bound (1996)', 'North by Northwest (1959)', 'Lawrence of Arabia (1962)', 'Star Trek: First Contact (1996)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"], 181: ['Hoop Dreams (1994)', 'Wallace & Gromit: A Close Shave (1995)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Lawrence of Arabia (1962)', 'Touch of Evil (1958)'], 219: ['Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Toy Story 3 (2010)', 'Inception (2010)'], 222: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Lord of the Rings: The Return of the King, The (2003)'], 234: ['African Queen, The (1951)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Clockwork Orange, A (1971)', 'Raising Arizona (1987)', 'Casino Royale (2006)'], 235: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Apocalypse Now (1979)', 'Goodfellas (1990)', 'Fight Club (1999)', 'There Will Be Blood (2007)'], 240: ['Three Colors: Red (Trois couleurs: Rouge) (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Princess Bride, The (1987)', 'Lawrence of Arabia (1962)', 'Fantastic Mr. Fox (2009)'], 284: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Touch of Evil (1958)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Lord of the Rings: The Return of the King, The (2003)'], 287: ["Monty Python's Life of Brian (1979)", 'Alien (1979)', 'Groundhog Day (1993)', 'Old Boy (2003)', 'Departed, The (2006)'], 288: ['Godfather, The (1972)', 'Godfather: Part II, The (1974)',  ...
# Rekomendacje po obejrzeniu 'Flint': {6: ['Star Wars: Episode IV - A New Hope (1977)', 'Ghost in the Shell (Kôkaku kidôtai) (1995)', 'Wallace & Gromit: A Close Shave (1995)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode VI - Return of the Jedi (1983)'], 15: ['Hoop Dreams (1994)', 'Goodfellas (1990)', 'Indiana Jones and the Last Crusade (1989)', 'Good Will Hunting (1997)', 'Run Lola Run (Lola rennt) (1998)'], 21: ['Secrets & Lies (1996)', 'Streetcar Named Desire, A (1951)', 'Paths of Glory (1957)', 'Lawrence of Arabia (1962)', 'In Bruges (2008)'], 38: ['Godfather, The (1972)', 'Casablanca (1942)', 'Godfather: Part II, The (1974)', 'Fight Club (1999)', 'Hustler, The (1961)'], 43: ['Sense and Sensibility (1995)', 'Persuasion (1995)', 'Dead Man Walking (1995)', 'Usual Suspects, The (1995)', 'Lamerica (1994)'], 57: ['Shawshank Redemption, The (1994)', 'Brazil (1985)', 'Army of Darkness (1993)', 'Fight Club (1999)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"], 64: ["Monty Python's Life of Brian (1979)", 'Brazil (1985)', 'Boot, Das (Boat, The) (1981)', 'Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986)', 'There Will Be Blood (2007)'], 68: ['Lawrence of Arabia (1962)', 'Patton (1970)', 'Miracle on 34th Street (1947)', 'Badlands (1973)', 'Dogville (2003)'], 109: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Casablanca (1942)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Departed, The (2006)', 'There Will Be Blood (2007)'], 132: ['Lawrence of Arabia (1962)', 'Goodfellas (1990)', 'Amadeus (1984)', 'Sting, The (1973)', 'Seventh Seal, The (Sjunde inseglet, Det) (1957)'], 136: ['Shawshank Redemption, The (1994)', 'Great Escape, The (1963)', 'Fight Club (1999)', 'For a Few Dollars More (Per qualche dollaro in più) (1965)', 'Lord of the Rings: The Return of the King, The (2003)'], 170: ['North by Northwest (1959)', "One Flew Over the Cuckoo's Nest (1975)", 'Lawrence of Arabia (1962)', 'Boondock Saints, The (2000)', 'Spirited Away (Sen to Chihiro no kamikakushi) (2001)'], 177: ['Bound (1996)', 'North by Northwest (1959)', 'Lawrence of Arabia (1962)', 'Star Trek: First Contact (1996)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)"], 181: ['Hoop Dreams (1994)', 'Wallace & Gromit: A Close Shave (1995)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Lawrence of Arabia (1962)', 'Touch of Evil (1958)'], 219: ['Sunset Blvd. (a.k.a. Sunset Boulevard) (1950)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Good, the Bad and the Ugly, The (Buono, il brutto, il cattivo, Il) (1966)', 'Toy Story 3 (2010)', 'Inception (2010)'], 222: ['Shawshank Redemption, The (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Star Wars: Episode V - The Empire Strikes Back (1980)', 'Princess Bride, The (1987)', 'Lord of the Rings: The Return of the King, The (2003)'], 234: ['African Queen, The (1951)', 'Wallace & Gromit: The Wrong Trousers (1993)', 'Clockwork Orange, A (1971)', 'Raising Arizona (1987)', 'Casino Royale (2006)'], 235: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Apocalypse Now (1979)', 'Goodfellas (1990)', 'Fight Club (1999)', 'There Will Be Blood (2007)'], 240: ['Three Colors: Red (Trois couleurs: Rouge) (1994)', 'Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Princess Bride, The (1987)', 'Lawrence of Arabia (1962)', 'Fantastic Mr. Fox (2009)'], 284: ['Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964)', 'Touch of Evil (1958)', "Amelie (Fabuleux destin d'Amélie Poulain, Le) (2001)", 'Lord of the Rings: The Fellowship of the Ring, The (2001)', 'Lord of the Rings: The Return of the King, The (2003)'], 287: ["Monty Python's Life of Brian (1979)", 'Alien (1979)', 'Groundhog Day (1993)', 'Old Boy (2003)', 'Departed, The (2006)'], 288: ['Godfather, The (1972)', 'Godfather: Part II, The (1974)',  ...
